# %%
import cellxgene_census
import scanpy as sc

# %%
with cellxgene_census.open_soma() as census:
    adata = cellxgene_census.get_anndata(
        census = census,
        organism = "Homo sapiens",
        obs_value_filter = "tissue_general == 'bone marrow' and disease =='normal'",)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 605318 × 60664
#     obs: 'soma_joinid', 'dataset_id', 'assay', 'assay_ontology_term_id', 'cell_type', 'cell_type_ontology_term_id', 'development_stage', 'development_stage_ontology_term_id', 'disease', 'disease_ontology_term_id', 'donor_id', 'is_primary_data', 'self_reported_ethnicity', 'self_reported_ethnicity_ontology_term_id', 'sex', 'sex_ontology_term_id', 'suspension_type', 'tissue', 'tissue_ontology_term_id', 'tissue_general', 'tissue_general_ontology_term_id'
#     var: 'soma_joinid', 'feature_id', 'feature_name', 'feature_length'

# %%
adata.obs
# Out:
#         soma_joinid                            dataset_id          assay  \
# 0          14040198  471647b3-04fe-4c76-8372-3264feb950e8      10x 3' v3
# 1          14040199  471647b3-04fe-4c76-8372-3264feb950e8      10x 3' v3
# 2          14040200  471647b3-04fe-4c76-8372-3264feb950e8      10x 3' v3
# 3          14040201  471647b3-04fe-4c76-8372-3264feb950e8      10x 3' v3
# 4          14040202  471647b3-04fe-4c76-8372-3264feb950e8      10x 3' v3
# ...             ...                                   ...            ...
# 605313     46847420  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
# 605314     46847421  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
# 605315     46847422  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
# 605316     46847423  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
# 605317     46847424  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
#
#        assay_ontology_term_id                                    cell_type  \
# 0                 EFO:0009922  lymphoid lineage restricted progenitor cell
# 1                 EFO:0009922                                   pro-B cell
# 2                 EFO:0009922                   common lymphoid progenitor
# 3                 EFO:0009922                                   pro-B cell
# 4                 EFO:0009922  lymphoid lineage restricted progenitor cell
# ...                       ...                                          ...
# 605313            EFO:0030002         professional antigen presenting cell
# 605314            EFO:0030002         professional antigen presenting cell
# 605315            EFO:0030002         professional antigen presenting cell
# 605316            EFO:0030002         professional antigen presenting cell
# 605317            EFO:0030002         professional antigen presenting cell
#
#        cell_type_ontology_term_id        development_stage  \
# 0                      CL:0000838                  unknown
# 1                      CL:0000826                  unknown
# 2                      CL:0000051                  unknown
# 3                      CL:0000826                  unknown
# 4                      CL:0000838                  unknown
# ...                           ...                      ...
# 605313                 CL:0000145  49-year-old human stage
# 605314                 CL:0000145  49-year-old human stage
# 605315                 CL:0000145  49-year-old human stage
# 605316                 CL:0000145  49-year-old human stage
# 605317                 CL:0000145  49-year-old human stage
#
#        development_stage_ontology_term_id disease disease_ontology_term_id  \
# 0                                 unknown  normal             PATO:0000461
# 1                                 unknown  normal             PATO:0000461
# 2                                 unknown  normal             PATO:0000461
# 3                                 unknown  normal             PATO:0000461
# 4                                 unknown  normal             PATO:0000461
# ...                                   ...     ...                      ...
# 605313                     HsapDv:0000143  normal             PATO:0000461
# 605314                     HsapDv:0000143  normal             PATO:0000461
# 605315                     HsapDv:0000143  normal             PATO:0000461
# 605316                     HsapDv:0000143  normal             PATO:0000461
# 605317                     HsapDv:0000143  normal             PATO:0000461
#
#         ... is_primary_data  self_reported_ethnicity  \
# 0       ...            True                  unknown
# 1       ...            True                  unknown
# 2       ...            True                  unknown
# 3       ...            True                  unknown
# 4       ...            True                  unknown
# ...     ...             ...                      ...
# 605313  ...            True              Han Chinese
# 605314  ...            True              Han Chinese
# 605315  ...            True              Han Chinese
# 605316  ...            True              Han Chinese
# 605317  ...            True              Han Chinese
#
#        self_reported_ethnicity_ontology_term_id      sex sex_ontology_term_id  \
# 0                                       unknown  unknown              unknown
# 1                                       unknown  unknown              unknown
# 2                                       unknown  unknown              unknown
# 3                                       unknown  unknown              unknown
# 4                                       unknown  unknown              unknown
# ...                                         ...      ...                  ...
# 605313                           HANCESTRO:0027   female         PATO:0000383
# 605314                           HANCESTRO:0027   female         PATO:0000383
# 605315                           HANCESTRO:0027   female         PATO:0000383
# 605316                           HANCESTRO:0027   female         PATO:0000383
# 605317                           HANCESTRO:0027   female         PATO:0000383
#
#        suspension_type       tissue tissue_ontology_term_id tissue_general  \
# 0                 cell  bone marrow          UBERON:0002371    bone marrow
# 1                 cell  bone marrow          UBERON:0002371    bone marrow
# 2                 cell  bone marrow          UBERON:0002371    bone marrow
# 3                 cell  bone marrow          UBERON:0002371    bone marrow
# 4                 cell  bone marrow          UBERON:0002371    bone marrow
# ...                ...          ...                     ...            ...
# 605313            cell  bone marrow          UBERON:0002371    bone marrow
# 605314            cell  bone marrow          UBERON:0002371    bone marrow
# 605315            cell  bone marrow          UBERON:0002371    bone marrow
# 605316            cell  bone marrow          UBERON:0002371    bone marrow
# 605317            cell  bone marrow          UBERON:0002371    bone marrow
#
#        tissue_general_ontology_term_id
# 0                       UBERON:0002371
# 1                       UBERON:0002371
# 2                       UBERON:0002371
# 3                       UBERON:0002371
# 4                       UBERON:0002371
# ...                                ...
# 605313                  UBERON:0002371
# 605314                  UBERON:0002371
# 605315                  UBERON:0002371
# 605316                  UBERON:0002371
# 605317                  UBERON:0002371
#
# [605318 rows x 21 columns]

# %%
adata.var
# Out:
#        soma_joinid       feature_id   feature_name  feature_length
# 0                0  ENSG00000000003         TSPAN6            4536
# 1                1  ENSG00000000005           TNMD            1476
# 2                2  ENSG00000000419           DPM1            9276
# 3                3  ENSG00000000457          SCYL3            6883
# 4                4  ENSG00000000460       C1orf112            5970
# ...            ...              ...            ...             ...
# 60659        60659  ENSG00000288719  RP4-669P10.21            4252
# 60660        60660  ENSG00000288720  RP11-852E15.3            7007
# 60661        60661  ENSG00000288721   RP5-973N23.5            7765
# 60662        60662  ENSG00000288723  RP11-553N16.6            1015
# 60663        60663  ENSG00000288724   RP13-546I2.2             625
#
# [60664 rows x 4 columns]

# %%
print(adata.X[:10])
# Out:
#   (0, 38)	1.0
#   (0, 50)	1.0
#   (0, 52)	1.0
#   (0, 74)	1.0
#   (0, 75)	1.0
#   (0, 90)	2.0
#   (0, 99)	1.0
#   (0, 103)	1.0
#   (0, 105)	1.0
#   (0, 124)	1.0
#   (0, 173)	1.0
#   (0, 176)	3.0
#   (0, 191)	1.0
#   (0, 195)	1.0
#   (0, 196)	1.0
#   (0, 198)	1.0
#   (0, 229)	4.0
#   (0, 230)	1.0
#   (0, 232)	1.0
#   (0, 248)	2.0
#   (0, 251)	5.0
#   (0, 253)	1.0
#   (0, 323)	1.0
#   (0, 329)	1.0
#   (0, 337)	1.0
#   :	:
#   (9, 32128)	1.0
#   (9, 32316)	1.0
#   (9, 32358)	4.0
#   (9, 32454)	1.0
#   (9, 32585)	2.0
#   (9, 32595)	1.0
#   (9, 32792)	5.0
#   (9, 32821)	1.0
#   (9, 32853)	1.0
#   (9, 32866)	1.0
#   (9, 33016)	1.0
#   (9, 33056)	3.0
#   (9, 33095)	1.0
#   (9, 33129)	1.0
#   (9, 33161)	1.0
#   (9, 33211)	1.0
#   (9, 33223)	3.0
#   (9, 33322)	1.0
#   (9, 33374)	1.0
#   (9, 33508)	1.0
#   (9, 33522)	1.0
#   (9, 33553)	1.0
#   (9, 33740)	1.0
#   (9, 34158)	1.0
#   (9, 36362)	1.0

# %%
adata.write('bone-marrow_cell-census.h5ad',compression='gzip')
